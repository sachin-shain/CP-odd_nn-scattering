# %% [markdown]
# # Main file
#
# ### Note: running this file will generate all the results.

# %%
# %run c0_calc.ipynb
# Out:
# C0 calc for channels :  1S0
# Elab            : 10.0
# delta_0         : 59.9564
# (a,b)           : (-60.0,50.0)
# CPU times: user 199 ms, sys: 103 ms, total: 302 ms
# Wall time: 119 ms
# C0 calc for channels :  3P0
# Elab            : 10.0
# delta_0         : 3.6528
# (a,b)           : (-400.0,400.0)
# CPU times: user 271 ms, sys: 75.9 ms, total: 347 ms
# Wall time: 155 ms
# C0 calc for channels :  3S1 3D1
# Elab            : 10.0
# delta_0         : 102.6114
# (a,b)           : (-8000.0,8000.0)
# CPU times: user 201 ms, sys: 127 ms, total: 328 ms
# Wall time: 141 ms
# pot_even_dict._cache is same or smaller than the reference file. No action required.

# %%
# %run cp_even_plots.ipynb
# Out:
# CP-even plots for channels :  1S0
#
#
# Without contact term:
# With contact term:
# CP-even plots for channels :  3P0
#
#
# Without contact term:
# With contact term:
# CP-even plots for channels :  3S1 3D1
#
#
# Without contact term:
# With contact term:
# CP-even plots for channels :  3P1
#
#
# Without contact term:
# With contact term:
# CP-even plots for channels :  1P1
#
#
# Without contact term:
# With contact term:
# Length of local pot_even_dict._cache is same or smaller than the reference file. No further action required.

# %%
# %run comparision_plot.ipynb
# Out:
# CP-even plots for channels :  1S0
#
# Experimental data file found.
# C0 data file found.
# CP-even plots for channels :  3P0
#
# Experimental data file found.
# C0 data file found.
# CP-even plots for channels :  3S1 3D1
#
# Experimental data file found.
# C0 data file found.
# CP-even plots for channels :  3P1
#
# Experimental data file found.
# C0 data file found.
# CP-even plots for channels :  1P1
#
# Experimental data file found.
# C0 data file found.
