# %% [markdown]
# # Main file
#
# ### Note: run this file to get all the results

# %%
# %run cpv_counterterm.ipynb
# Out:
# Calculating counter term CP-odd C0(lam) for four values of esp_exp.
#
#    lam  e0_true = 0.01  e0_true = 0.11  e0_true = -0.09  not renorm
# 0  2.0        0.888454        1.067591         0.709317           0
# 1  2.1        0.875090        1.050320         0.699861           0
# 2  2.2        0.866117        1.038843         0.693391           0
# 3  2.3        0.861897        1.033523         0.690272           0
# 4  2.4        0.862963        1.034950         0.690977           0

# %%
# %run cpv_plots.ipynb
# Out:
# Ploting CP-odd j=0:
#
#
# e0_true = 0.01
# e0_true = 0.11
# e0_true = -0.09
# not renorm
# Data to make cp-odd j=1 plots.
#
#    lam  esp_10mev  esp_50mev  esp_100mev  esp_190mev  edp_10mev  edp_50mev  \
# 0  2.0 -10.535230 -14.168585  -16.416165  -16.524720   5.738809  26.884411
# 1  2.1 -10.119859 -13.407729  -15.812916  -17.048627   5.684197  26.578106
# 2  2.2  -9.694988 -12.607219  -15.070974  -17.173522   5.629628  26.254635
# 3  2.3  -9.270455 -11.787512  -14.226942  -16.989488   5.576135  25.927579
# 4  2.4  -8.853706 -10.965228  -13.311302  -16.561854   5.524450  25.606109
#
#    edp_100mev  edp_190mev
# 0   39.020184   41.413016
# 1   38.884118   44.119387
# 2   38.555710   45.698544
# 3   38.110546   46.439487
# 4   37.601396   46.589245
# potential _cache is same or smaller than the reference file. No action required.
